# %%
from src.python.cord19m.data_loader import Cord19

# %%
x = Cord19('data/',output_dir='models/')
# Out:
# output_dir models/
# Loading metadata from data/metadata.csv
# /opt/anaconda3/envs/gluonts/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3319: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Cleaning metadata

# %%
x.load_text_data()
# Out:
# 100%|██████████| 47296/47296 [03:34<00:00, 220.52it/s]
# Saving file

# %%
x.metadata.head()
# Out:
#    cord_uid                                       sha  source_x  \
# 0  8q5ondtn                                       NaN  Elsevier
# 1  pzfd0e50                                       NaN  Elsevier
# 2  22bka3gi                                       NaN  Elsevier
# 3  zp9k1k3z  aecbc613ebdab36753235197ffb4f35734b5ca63  Elsevier
# 4  cjuzul89                                       NaN  Elsevier
#
#                                                title  \
# 0  Intrauterine virus infections and congenital h...
# 1                  Coronaviruses in Balkan nephritis
# 2  Cigarette smoking and coronary heart disease: ...
# 3  Clinical and immunologic studies in identical ...
# 4  Epidemiology of community-acquired respiratory...
#
#                             doi pmcid pubmed_id    license  \
# 0  10.1016/0002-8703(72)90077-4   NaN   4361535  els-covid
# 1  10.1016/0002-8703(80)90355-5   NaN   6243850  els-covid
# 2  10.1016/0002-8703(80)90356-7   NaN   7355701  els-covid
# ...

# %%
x.df_docs.head(10)
# Out:
#    cord_uid  lsid  gsid      Name  \
# 0  8q5ondtn   1.0     1     TITLE
# 1  8q5ondtn   2.0     2  ABSTRACT
# 0  pzfd0e50   1.0     3     TITLE
# 1  pzfd0e50   2.0     4  ABSTRACT
# 0  22bka3gi   1.0     5     TITLE
# 1  22bka3gi   2.0     6  ABSTRACT
# 0  zp9k1k3z   1.0     7     TITLE
# 1  zp9k1k3z   2.0     8  ABSTRACT
# 2  zp9k1k3z   3.0     9   NO_NAME
# 3  zp9k1k3z   4.0    10  COMMENT:
#
#                                                 Text   Subtype
# 0  Intrauterine virus infections and congenital h...  metadata
# 1   The etiologic basis for the vast majority of ...  metadata
# 0                  Coronaviruses in Balkan nephritis  metadata
# 1                  Coronaviruses in Balkan nephritis  metadata
# 0  Cigarette smoking and coronary heart disease: ...  metadata
# 1  Cigarette smoking and coronary heart disease: ...  metadata
# 0  Clinical and immunologic studies in identical ...  metadata
# 1   Middle-aged female identical twins, one of wh...  metadata
# ...
